# %%
# 경사하강법(Gradient descent method)에 대해 알아본다. 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 데이터를 생성해보자
# 보통 변수앞에 붙는 상수를 weight(가중치)라 하고, 뒤에 상수를 bias(편향)이라 한다.

def make_linear(w, b, size=50, noise = 1.0): # size 초기값을 50 / noise 초기값을 1.0 
# size, noise를 따로 지정하지 않으면 size와 noise는 50, 1.0이 된다(아래 그림 참고). 
  x=np.linspace(0,1,size)
  y_reg = w*x + b
  np.random.seed(10) # np.random.seed()를 고정, 난수의 생성패턴을 동일하게 관리
  noise = noise * np.random.normal(size = size) # 표준정규분포를 따르는 데이터 생성

  y = y_reg + noise

  return x, y, y_reg

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 출처: https://velog.io/@banana/Python-%ED%95%A8%EC%88%98

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 출처: https://frhyme.github.io/python-libs/np_random_get_set_state/

# %%
x, y, y_reg = make_linear(w = 1, b = 0, size = 200, noise = 0.1)

plt.figure(figsize = (8,6))
plt.plot(x, y_reg, 'r--', label = 'regression line', linewidth = 3)
plt.scatter(x, y, label = 'data', s = 10) # s는 size / c는 color
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
# ### Loss function을 최소화하는 parameter를 찾는 방법
#
# - Gradient descent method (Gradient: 해당 점에서 함숫값이 가장 크게 증가하는 방향)
# - Calculus analysis(해석적 방법)

# %% [markdown]
# ### Gradient descent
#
# ![image.png](data:image/png;base64,...)

# %%
w = 10
b = -10
y_hat = w*x + b

plt.figure(figsize = (8,6))
plt.plot(x, y_hat, 'r--', label = 'regression line', linewidth = 3)
plt.scatter(x, y, label = 'data', s = 10)
plt.legend(fontsize = 15)

plt.xlim([-0.05, 1.05]) # x축 표시범위 지정
plt.ylim([-0.5, 1.5]) # y축 표시범위 지정
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# xlim() 함수에 xmin, xmax 값을 각각 입력하거나 리스트 또는 튜플의 형태로 입력합니다.
#
# ylim() 함수에 ymin, ymax 값을 각각 입력하거나 리스트 또는 튜플의 형태로 입력합니다.

# %%
# 경사하강법

learning_rate = 0.5 # 학습률

# learning! : w와 b를 학습한다!
w = w - learning_rate * ((y_hat - y) * x).mean() 
b = b - learning_rate * (y_hat - y).mean()

loss = ((y - y_hat)**2).mean() / 2

# update된 parameter 적용시키기

y_hat = w*x + b


# 시각화
plt.figure(figsize = (8,6))
plt.plot(x, y_hat, 'r--', label = 'regression line', linewidth = 3)
plt.scatter(x, y, label = 'data', s = 10)
plt.text(0.6, 0.25, "w : {:1.3f}, b : {:1.3f}".format(w,b), fontsize = 15)
plt.text(0.6, 0.15, "loss : {:1.5f}".format(loss), fontsize = 15)

plt.legend(fontsize = 15)

plt.xlim([-0.05, 1.05])
plt.ylim([-0.5, 1.5])
plt.show()

# %%
# 자동으로 계속 반복해보자!

w_list = [] 
b_list = []
loss_list = []

# inital setting 
w = 10
b = -10
learning_rate = 0.002 # 학습률(알파 생각하면 됨.)
num_epoch = 50000


# 반복횟수만큼 하는게 너무 비효율적일 수 있으니, 조건을 걸어 break 한다!

for epoch in range(num_epoch):
  y_hat = w*x + b

  w = w - learning_rate * ((y_hat - y) * x).mean() 
  b = b - learning_rate * (y_hat - y).mean()

  loss = ((y - y_hat)**2).mean() / 2

  if loss < 0.00001: # 약간 최적설계때 느낌난다. (손실이 ~보다 작을 때 반복 멈추기) 
    print("{} 번 실행 후 종료".format(epoch))
    break

  loss_list.append(loss)
  w_list.append(w)
  b_list.append(b)

  if epoch % 500 == 0: # 500배수 번의 반복마다 출력
    print("{} epoch | w = {:1.3f}, b = {:1.3f}, loss = {:1.5f}".format(epoch, w, b, loss))

  
print(w, b, loss)
# Out:
# 0 epoch | w = 10.004, b = -9.989, loss = 18.58460
# 500 epoch | w = 10.835, b = -6.714, loss = 5.71461
# 1000 epoch | w = 10.599, b = -5.542, loss = 4.17076
# 1500 epoch | w = 10.093, b = -4.978, loss = 3.58686
# 2000 epoch | w = 9.540, b = -4.599, loss = 3.13621
# 2500 epoch | w = 9.000, b = -4.286, loss = 2.74639
# 3000 epoch | w = 8.488, b = -4.006, loss = 2.40543
# 3500 epoch | w = 8.007, b = -3.746, loss = 2.10689
# 4000 epoch | w = 7.557, b = -3.505, loss = 1.84548
# 4500 epoch | w = 7.135, b = -3.279, loss = 1.61658
# 5000 epoch | w = 6.741, b = -3.067, loss = 1.41614
# 5500 epoch | w = 6.371, b = -2.870, loss = 1.24063
# 6000 epoch | w = 6.026, b = -2.684, loss = 1.08695
# 6500 epoch | w = 5.703, b = -2.511, loss = 0.95237
# 7000 epoch | w = 5.400, b = -2.349, loss = 0.83453
# 7500 epoch | w = 5.117, b = -2.198, loss = 0.73135
# 8000 epoch | w = 4.852, b = -2.056, loss = 0.64099
# 8500 epoch | w = 4.604, b = -1.923, loss = 0.56188
# 9000 epoch | w = 4.372, b = -1.799, loss = 0.49260
# 9500 epoch | w = 4.155, b = -1.683, loss = 0.43193
# 10000 epoch | w = 3.952, b = -1.574, loss = 0.37881
# 10500 epoch | w = 3.762, b = -1.472, loss = 0.33230
# 11000 epoch | w = 3.584, b = -1.377, loss = 0.29157
# 11500 epoch | w = 3.418, b = -1.288, loss = 0.25590
# 12000 epoch | w = 3.262, b = -1.204, loss = 0.22467
# 12500 epoch | w = 3.116, b = -1.126, loss = 0.19733
# 13000 epoch | w = 2.980, b = -1.053, loss = 0.17338
# 13500 epoch | w = 2.852, b = -0.985, loss = 0.15241
# 14000 epoch | w = 2.733, b = -0.921, loss = 0.13405
# 14500 epoch | w = 2.621, b = -0.861, loss = 0.11797
# 15000 epoch | w = 2.517, b = -0.805, loss = 0.10390
# 15500 epoch | w = 2.419, b = -0.753, loss = 0.09157
# 16000 epoch | w = 2.327, b = -0.704, loss = 0.08077
# 16500 epoch | w = 2.241, b = -0.658, loss = 0.07132
# 17000 epoch | w = 2.161, b = -0.615, loss = 0.06304
# 17500 epoch | w = 2.086, b = -0.575, loss = 0.05580
# 18000 epoch | w = 2.016, b = -0.537, loss = 0.04945
# 18500 epoch | w = 1.950, b = -0.502, loss = 0.04389
# 19000 epoch | w = 1.889, b = -0.469, loss = 0.03903
# 19500 epoch | w = 1.831, b = -0.438, loss = 0.03477
# 20000 epoch | w = 1.778, b = -0.409, loss = 0.03104
# 20500 epoch | w = 1.727, b = -0.382, loss = 0.02777
# 21000 epoch | w = 1.680, b = -0.357, loss = 0.02491
# 21500 epoch | w = 1.636, b = -0.333, loss = 0.02240
# 22000 epoch | w = 1.595, b = -0.311, loss = 0.02021
# 22500 epoch | w = 1.556, b = -0.291, loss = 0.01829
# 23000 epoch | w = 1.520, b = -0.271, loss = 0.01661
# 23500 epoch | w = 1.486, b = -0.253, loss = 0.01513
# 24000 epoch | w = 1.454, b = -0.236, loss = 0.01384
# 24500 epoch | w = 1.425, b = -0.220, loss = 0.01272
# 25000 epoch | w = 1.397, b = -0.205, loss = 0.01173
# 25500 epoch | w = 1.371, b = -0.192, loss = 0.01086
# 26000 epoch | w = 1.347, b = -0.179, loss = 0.01010
# 26500 epoch | w = 1.324, b = -0.166, loss = 0.00944
# 27000 epoch | w = 1.303, b = -0.155, loss = 0.00886
# 27500 epoch | w = 1.283, b = -0.144, loss = 0.00835
# 28000 epoch | w = 1.264, b = -0.134, loss = 0.00790
# 28500 epoch | w = 1.247, b = -0.125, loss = 0.00751
# 29000 epoch | w = 1.231, b = -0.116, loss = 0.00717
# 29500 epoch | w = 1.215, b = -0.108, loss = 0.00687
# 30000 epoch | w = 1.201, b = -0.101, loss = 0.00661
# 30500 epoch | w = 1.188, b = -0.093, loss = 0.00638
# 31000 epoch | w = 1.175, b = -0.087, loss = 0.00618
# 31500 epoch | w = 1.164, b = -0.080, loss = 0.00600
# 32000 epoch | w = 1.153, b = -0.075, loss = 0.00585
# 32500 epoch | w = 1.142, b = -0.069, loss = 0.00571
# 33000 epoch | w = 1.133, b = -0.064, loss = 0.00560
# 33500 epoch | w = 1.124, b = -0.059, loss = 0.00549
# 34000 epoch | w = 1.116, b = -0.055, loss = 0.00540
# 34500 epoch | w = 1.108, b = -0.050, loss = 0.00532
# 35000 epoch | w = 1.100, b = -0.047, loss = 0.00525
# 35500 epoch | w = 1.093, b = -0.043, loss = 0.00519
# 36000 epoch | w = 1.087, b = -0.039, loss = 0.00514
# 36500 epoch | w = 1.081, b = -0.036, loss = 0.00509
# 37000 epoch | w = 1.075, b = -0.033, loss = 0.00505
# 37500 epoch | w = 1.070, b = -0.030, loss = 0.00502
# 38000 epoch | w = 1.065, b = -0.028, loss = 0.00498
# 38500 epoch | w = 1.061, b = -0.025, loss = 0.00496
# 39000 epoch | w = 1.056, b = -0.023, loss = 0.00493
# 39500 epoch | w = 1.052, b = -0.021, loss = 0.00491
# 40000 epoch | w = 1.048, b = -0.019, loss = 0.00489
# 40500 epoch | w = 1.045, b = -0.017, loss = 0.00488
# 41000 epoch | w = 1.042, b = -0.015, loss = 0.00486
# 41500 epoch | w = 1.039, b = -0.013, loss = 0.00485
# 42000 epoch | w = 1.036, b = -0.012, loss = 0.00484
# 42500 epoch | w = 1.033, b = -0.010, loss = 0.00483
# 43000 epoch | w = 1.030, b = -0.009, loss = 0.00482
# 43500 epoch | w = 1.028, b = -0.008, loss = 0.00481
# 44000 epoch | w = 1.026, b = -0.007, loss = 0.00481
# 44500 epoch | w = 1.024, b = -0.005, loss = 0.00480
# 45000 epoch | w = 1.022, b = -0.004, loss = 0.00480
# 45500 epoch | w = 1.020, b = -0.003, loss = 0.00479
# 46000 epoch | w = 1.018, b = -0.003, loss = 0.00479
# 46500 epoch | w = 1.017, b = -0.002, loss = 0.00479
# 47000 epoch | w = 1.015, b = -0.001, loss = 0.00478
# 47500 epoch | w = 1.014, b = -0.000, loss = 0.00478
# 48000 epoch | w = 1.012, b = 0.001, loss = 0.00478
# 48500 epoch | w = 1.011, b = 0.001, loss = 0.00478
# 49000 epoch | w = 1.010, b = 0.002, loss = 0.00478
# 49500 epoch | w = 1.009, b = 0.002, loss = 0.00477
# 1.0079716463860935 0.0029258016410707408 0.004772513829431017

# %%
# 시각화
plt.figure(figsize = (8,6))
plt.plot(x, y_hat, 'r--', label = 'regression line', linewidth = 3)
plt.scatter(x, y, label = 'data', s = 10)
plt.text(0.6, 0.25, "w : {:1.3f}, b : {:1.3f}".format(w,b), fontsize = 15)
plt.text(0.6, 0.15, "loss : {:1.5f}".format(loss), fontsize = 15)

plt.legend(fontsize = 15)

plt.xlim([-0.05, 1.05])
plt.ylim([-0.5, 1.5])
plt.show()

# %%
# loss 시각화 하기.

# loss_list에 loss를 append 해주었으므로
plt.plot(loss_list) 
plt.title("loss for epoch")
plt.xlabel("epoch") # x축은 반복수. loss가 append될 때, epoch에 따른 loss가 append 됐으므로
plt.ylabel("loss")
plt.show()

# %%
# 해석적 방법

X, Y, y_reg = make_linear(w = 1, b = 0, size = 200, noise = 0.1)

np.cov(X,Y)
# 공분산(covariance): 두 변수가 함께 변화하는 정도를 나타내는 지표
# np.cov를 사용하면 x의 분산, y의 분산과 함께 x와 y의 공분산을 계산
# Out:
# array([[0.08459382, 0.08403326],
#        [0.08403326, 0.09305109]])

# %% [markdown]
# -> 공분산은 0.08403326

# %%
w = (np.cov(X,Y)[0,1]) / np.var(X)
b = Y.mean() - w * X.mean()

Y_hat = w*X + b

loss = ((Y - Y_hat)**2).mean() / 2

# %%
# 시각화
plt.figure(figsize = (8,6))
plt.plot(X, Y_hat, 'r--', label = 'regression line', linewidth = 3)
plt.scatter(X, Y, label = 'data', s = 10)
plt.text(0.6, 0.25, "w : {:1.3f}, b : {:1.3f}".format(w,b), fontsize = 15)
plt.text(0.6, 0.15, "loss : {:1.5f}".format(loss), fontsize = 15)

plt.legend(fontsize = 15)

plt.xlim([-0.05, 1.05])
plt.ylim([-0.5, 1.5])
plt.show()

# %%
# R2 score: 결정계수(회귀 분석에서 사용하는 수치)
# R2 = 1 - SSE/SST (SST는 총 제곱합 / SSE는 회귀 제곱합)

X, Y, y_reg = make_linear(w = 1, b =0, size = 200, noise = 0.1)

w = -5
b = 10

Y_bar = Y.mean()
Y_hat = w*X + b

SST = sum((Y_bar - y) ** 2)
SSE = sum((Y - Y_hat) ** 2)
SSR = SST - SSE # 잔차제곱합

R2_score = 1 - SSE/SST
print(R2_score)


# 시각화
plt.figure(figsize = (8,6))
plt.plot(X, Y_hat, 'r--', label = 'regression line', linewidth = 3)
plt.scatter(X, Y, label = 'data', s = 10)
plt.text(0.6, 0.25, "w : {:1.3f}, b : {:1.3f}".format(w,b), fontsize = 15)
plt.text(0.6, 0.15, "R2 score : {:1.5f}".format(R2_score), fontsize = 15)

plt.legend(fontsize = 15)

plt.xlim([-0.05, 1.05])
plt.ylim([-0.5, 1.5])
plt.show()
# Out:
# -559.8742633538625

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 문제1 

def LR_GD(X, Y, w, b, num_epoch, learning_rate):
  # w_list = []
  # b_list = []
  loss_list = []

  for epoch in range(num_epoch):
    Y_hat = w*X + b

    w = w - learning_rate * ((Y_hat - Y) * X).mean() 
    b = b - learning_rate * (Y_hat - Y).mean()

    loss = ((Y - Y_hat)**2).mean() / 2

    if loss < 0.00005:
      print("{} 번 실행 후 종료".format(epoch))
      break

    loss_list.append(loss)
    # w_list.append(w)
    # b_list.append(b)

    if epoch % 500 == 0:
      print("{} epoch | w = {:1.3f}, b = {:1.3f}, loss = {:1.5f}".format(epoch, w, b, loss))

  return w, b, loss, loss_list

# %%
X, Y, y_reg = make_linear(w = 1, b = 0, size = 300, noise = 0.1)

w = -1
b = 1

Y_hat = w*X + b

# 시각화
plt.figure(figsize = (8,6))
plt.plot(X, Y_hat, 'r--', label = 'regression line', linewidth = 3)
plt.scatter(X, Y, label = 'data', s = 10)
plt.text(0.6, 0.25, "w : {:1.3f}, b : {:1.3f}".format(w,b), fontsize = 15)
# plt.text(0.6, 0.15, "loss : {:1.5f}".format(R2_score), fontsize = 15)

plt.legend(fontsize = 15)

plt.xlim([-0.05, 1.05])
plt.ylim([-0.5, 1.5])
plt.show()

# %%
learning = 0.001
num_epoch = 20000

w, b, loss, loss_list = LR_GD(X, Y, w, b, num_epoch, learning_rate)
# Out:
# 0 epoch | w = -1.000, b = 1.000, loss = 0.17044
# 500 epoch | w = -0.852, b = 0.974, loss = 0.14769
# 1000 epoch | w = -0.728, b = 0.923, loss = 0.12977
# 1500 epoch | w = -0.617, b = 0.868, loss = 0.11424
# 2000 epoch | w = -0.514, b = 0.814, loss = 0.10064
# 2500 epoch | w = -0.417, b = 0.763, loss = 0.08873
# 3000 epoch | w = -0.327, b = 0.714, loss = 0.07830
# 3500 epoch | w = -0.243, b = 0.669, loss = 0.06916
# 4000 epoch | w = -0.164, b = 0.627, loss = 0.06115
# 4500 epoch | w = -0.090, b = 0.588, loss = 0.05414
# 5000 epoch | w = -0.021, b = 0.551, loss = 0.04799
# 5500 epoch | w = 0.043, b = 0.516, loss = 0.04261
# 6000 epoch | w = 0.104, b = 0.484, loss = 0.03789
# 6500 epoch | w = 0.161, b = 0.453, loss = 0.03376
# 7000 epoch | w = 0.214, b = 0.425, loss = 0.03014
# 7500 epoch | w = 0.263, b = 0.398, loss = 0.02697
# 8000 epoch | w = 0.310, b = 0.373, loss = 0.02420
# 8500 epoch | w = 0.353, b = 0.350, loss = 0.02176
# 9000 epoch | w = 0.394, b = 0.328, loss = 0.01963
# 9500 epoch | w = 0.432, b = 0.308, loss = 0.01777
# 10000 epoch | w = 0.468, b = 0.289, loss = 0.01613
# 10500 epoch | w = 0.501, b = 0.271, loss = 0.01470
# 11000 epoch | w = 0.532, b = 0.254, loss = 0.01344
# 11500 epoch | w = 0.561, b = 0.239, loss = 0.01234
# 12000 epoch | w = 0.589, b = 0.224, loss = 0.01138
# 12500 epoch | w = 0.614, b = 0.210, loss = 0.01054
# 13000 epoch | w = 0.638, b = 0.197, loss = 0.00980
# 13500 epoch | w = 0.661, b = 0.185, loss = 0.00915
# 14000 epoch | w = 0.682, b = 0.174, loss = 0.00858
# 14500 epoch | w = 0.701, b = 0.164, loss = 0.00808
# 15000 epoch | w = 0.720, b = 0.154, loss = 0.00765
# 15500 epoch | w = 0.737, b = 0.145, loss = 0.00727
# 16000 epoch | w = 0.753, b = 0.136, loss = 0.00693
# 16500 epoch | w = 0.768, b = 0.128, loss = 0.00664
# 17000 epoch | w = 0.782, b = 0.120, loss = 0.00638
# 17500 epoch | w = 0.795, b = 0.113, loss = 0.00616
# 18000 epoch | w = 0.808, b = 0.107, loss = 0.00596
# 18500 epoch | w = 0.819, b = 0.100, loss = 0.00579
# 19000 epoch | w = 0.830, b = 0.095, loss = 0.00564
# 19500 epoch | w = 0.840, b = 0.089, loss = 0.00551

# %%
Y_hat = w*X + b

# 시각화
plt.figure(figsize = (8,6))
plt.plot(X, Y_hat, 'r--', label = 'regression line', linewidth = 3)
plt.scatter(X, Y, label = 'data', s = 10)
plt.text(0.6, 0.25, "w : {:1.3f}, b : {:1.3f}".format(w,b), fontsize = 15)
# plt.text(0.6, 0.15, "loss : {:1.5f}".format(R2_score), fontsize = 15)

plt.legend(fontsize = 15)

plt.xlim([-0.05, 1.05])
plt.ylim([-0.5, 1.5])
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
